# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from textblob import TextBlob
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import emoji

# %%
df = pd.read_csv(r"C:\Users\anees\Data Analysis\Machine Learing\ML Data\emotions.csv")

# %%
df.head()
# Out:
#                                                 text  label
# 0  ive enjoyed being able to slouch about relax a...      0
# 1                         i dont know i feel so lost      0
# 2         i was beginning to feel quite disheartened      0
# 3  i can still lose the weight without feeling de...      0
# 4  im feeling a little like a damaged tree and th...      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    12000 non-null  object
#  1   label   12000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 187.6+ KB

# %%
df['text'][11000]
# Out:
# 'i just know that i feel like writing all the time and i m always stunned at how much i accomplish even when i m constantly busy'

# %%
# Emoition analysis
plt.figure(figsize= (10, 6))
plt.title('Emoition Analysis Distribution')
sns.countplot(x=df['label'])
plt.show()

# %%
df.dropna(inplace = True)

# %%
df[df['text'].isna()][['text', 'label']]
# Out:
# Empty DataFrame
# Columns: [text, label]
# Index: []

# %%
df['text'].str.lower()
# Out:
# 0        ive enjoyed being able to slouch about relax a...
# 1                               i dont know i feel so lost
# 2               i was beginning to feel quite disheartened
# 3        i can still lose the weight without feeling de...
# 4        im feeling a little like a damaged tree and th...
#                                ...
# 11995    i feel weird using his first name but the alte...
# 11996    i read them i feel pleasantly surprised that t...
# 11997         i feel a strange sense of guilt about it all
# 11998    i let people know how i m actually feeling and...
# 11999    i told him that my medication was making me fe...
# Name: text, Length: 12000, dtype: object

# %%
df
# Out:
#                                                     text  label
# 0      ive enjoyed being able to slouch about relax a...      0
# 1                             i dont know i feel so lost      0
# 2             i was beginning to feel quite disheartened      0
# 3      i can still lose the weight without feeling de...      0
# 4      im feeling a little like a damaged tree and th...      0
# ...                                                  ...    ...
# 11995  i feel weird using his first name but the alte...      5
# 11996  i read them i feel pleasantly surprised that t...      5
# 11997       i feel a strange sense of guilt about it all      5
# 11998  i let people know how i m actually feeling and...      5
# 11999  i told him that my medication was making me fe...      5
#
# [12000 rows x 2 columns]

# %%
def eda(data,column):
    count = 0
    count = data[column].apply(lambda x: count + emoji.emoji_count(x)).sum()  #emoji count in the data
    upper =data[column].str.isupper().sum()
    url = data[column].apply(lambda x:   True  if re.search(r'www.\S+ | https?://\S+',x)  else False).sum()
    tags = data[column].apply(lambda x:   True  if re.search(r'<[^>]>+',x)  else False).sum()
    marks = data[column].apply(lambda x:   True  if re.search(r'[^a-zA-Z0-9 ]',x)  else False).sum()
    digits = data[column].apply(lambda x:   True  if re.search(r'[0-9]',x)  else False).sum()
    return  pd.Series({'Emoji':count,"upper case":upper,"urls" : url,"HTML tags":tags,'Punctuaton':marks,'Digits':digits})

# %%
eda(df,"text")
# Out:
# Emoji         0
# upper case    0
# urls          0
# HTML tags     0
# Punctuaton    0
# Digits        0
# dtype: int64

# %%
#df.to_csv('Emotion_Analysis.csv')

# %% [markdown]
# # Bag of Words(Count of words)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow = CountVectorizer(stop_words='english', max_features=12000)

# %%
bow.fit(df['text'])
X = bow.transform(df['text'])
y = df['label']

# %%
bow.vocabulary_
# Out:
# {'ive': 5287,
#  'enjoyed': 3765,
#  'able': 17,
#  'slouch': 9464,
#  'relax': 8374,
#  'unwind': 11212,
#  'frankly': 4322,
#  'needed': 6616,
#  'weeks': 11619,
#  'end': 3724,
#  'uni': 11127,
#  'expo': 4004,
#  'lately': 5489,
#  'started': 9835,
#  'feeling': 4184,
#  'bit': 1140,
#  'listless': 5718,
#  'really': 8208,
#  'good': 4518,
#  'thing': 10558,
#  'dont': 3343,
#  'know': 5407,
#  'feel': 4179,
#  'lost': 5810,
#  'beginning': 1012,
#  'quite': 8068,
#  'disheartened': 3227,
#  'lose': 5804,
#  'weight': 11627,
#  'deprived': 3005,
#  'im': 5092,
#  'little': 5726,
#  'like': 5658,
#  'damaged': 2763,
#  'tree': 10856,
#  'roots': 8721,
#  'wack': 11485,
#  'stupid': 10034,
#  'realise': 8194,
#  'late': 5487,
#  'don': 3335,
#  'submissive': 10058,
#  'time': 10646,
#  've': 11327,
#  'bdsm': 966,
#  'stuff': 10023,
#  'imagine': 5098,
#  'just': 5353,
#  'reasons': 8222,
#  'marriage': 6017,
#  'hard': 4778,
#  'theyll': 10551,
#  'bad': 850,
#  'ugly': 11011,
#  'parts': 7208,
#  'make': 5928,
#  'love': 5823,
#  'feels': 4187,
#  'awful': 814,
#  'exposed': 4007,
#  'people': 7303,
#  'real': 8192,
#  'fan': 4098,
#  'fake': 4083,
#  'making': 5933,
#  'connections': 2323,
#  'pretty': 7768,
#  'homesick': 4987,
#  'week': 11615,
#  'message': 6183,
#  'does': 3315,
#  'reply': 8462,
#  'news': 6670,
#  'jason': 5301,
#  'observation': 6842,
#  'helpful': 4889,
#  'restating': 8544,
#  'truth': 10926,
#  'learned': 5548,
#  'years': 11919,
#  'ago': 256,
#  'wife': 11710,
#  'went': 11642,
#  'times': 10649,
#  'trust': 10922,
#  'lot': 5811,
#  'letting': 5605,
#  'admit': 174,
#  'inspiration': 5198,
#  'direction': 3168,
#  'melancholy': 6131,
#  'won': 11794,
#  'href': 5035,
#  'http': 5036,
#  'www': 11889,
#  'hopeless': 5004,
#  'future': 4381,
#  'life': 5633,
#  'kinda': 5387,
#  'come': 2150,
#  'wont': 11804,
#  'returnable': 8575,
#  'defect': 2892,
#  'began': 1007,
#  'doomed': 3344,
#  'neglectful': 6631,
#  'responding': 8535,
#  'comments': 2173,
#  'havent': 4807,
#  'eye': 4036,
#  'hate': 4792,
#  'seeing': 9025,
#  'nekkid': 6640,
#  'sounds': 9630,
#  'vain': 11289,
#  'think': 10560,
#  'look': 5787,
#  'horrendous': 5014,
#  'lousy': 5821,
#  'wondering': 11799,
#  'vlcd': 11447,
#  'hcg': 4814,
#  'cycle': 2744,
#  'knew': 5403,
#  'doing': 3322,
#  'completely': 2225,
#  'helpless': 4891,
#  'got': 4544,
#  'high': 4939,
#  'random': 8124,
#  'didnt': 3118,
#  'awkward': 817,
#  'year': 11915,
#  'anymore': 498,
#  'saying': 8904,
#  'trying': 10931,
#  'learn': 5547,
#  'theres': 10544,
#  'day': 2815,
#  'let': 5598,
#  'lifetime': 5638,
#  'required': 8486,
#  'unfortunate': 11111,
#  'fact': 4060,
#  'family': 4095,
#  'cat': 1708,
#  'recently': 8243,
#  'passed': 7214,
#  'away': 810,
#  'suppose': 10170,
#  'burdened': 1509,
#  'lauterbach': 5507,
#  'victimized': 11377,
#  'noticing': 6773,
#  'easy': 3545,
#  'waver': 11572,
#  'excitement': 3929,
#  'engagement': 3750,
#  'everyday': 3884,
#  'mundane': 6491,
#  'fun': 4369,
#  'sparkly': 9652,
#  'shiny': 9231,
#  'absolute': 32,
#  'desperate': 3040,
#  'misery': 6289,
#  'guilt': 4682,
#  'miserable': 6288,
#  'devastated': 3077,
#  'skeptical': 9391,
#  'realizing': 8205,
#  'school': 8941,
#  'soon': 9604,
#  'bothered': 1322,
#  'past': 7223,
#  'present': 7746,
#  'challenges': 1779,
#  'referee': 8303,
#  'game': 4387,
#  'whiner': 11670,
#  'pain': 7119,
#  'compared': 2202,
#  'live': 5728,
#  'hope': 5000,
#  'recovery': 8279,
#  'chipping': 1909,
#  'heart': 4840,
#  'extremely': 4033,
#  'dull': 3486,
#  'cold': 2117,
#  'chisel': 1912,
#  'felt': 4196,
#  'way': 11576,
#  'stupider': 10035,
#  'word': 11813,
#  'remorseful': 8427,
#  'bandwagon': 890,
#  'awfully': 815,
#  'isolated': 5278,
#  'talk': 10330,
#  'things': 10559,
#  'useless': 11258,
#  'home': 4983,
#  'holidays': 4980,
#  'sister': 9368,
#  'hidden': 4935,
#  'kind': 5386,
#  'job': 5317,
#  'situation': 9379,
#  'pathetic': 7234,
#  'moment': 6358,
#  'gave': 4398,
#  'later': 5490,
#  'regret': 8337,
#  'affects': 225,
#  'suffering': 10105,
#  'downward': 3387,
#  'spiral': 9703,
#  'begin': 1010,
#  'test': 10489,
#  'therapy': 10539,
#  'decades': 2857,
#  'crazy': 2594,
#  'date': 2803,
#  'defeated': 2891,
#  'person': 7354,
#  'try': 10930,
#  'return': 8574,
#  'broke': 1433,
#  'boyfriend': 1346,
#  'relationship': 8368,
#  'track': 10780,
#  'guilty': 4684,
#  'carry': 1683,
#  'strong': 9999,
#  'attachments': 724,
#  'change': 1786,
#  'wondered': 11796,
#  'thought': 10576,
#  'needy': 6623,
#  'badly': 853,
#  'worthless': 11845,
#  'friends': 4344,
#  'ungrateful': 11118,
#  'honor': 4994,
#  'abused': 43,
#  'want': 11526,
#  'right': 8642,
#  'turn': 10955,
#  'exactly': 3901,
#  'imagined': 5099,
#  'wanted': 11527,
#  'thousand': 10580,
#  'goodness': 4524,
#  'sake': 8826,
#  'immediately': 5104,
#  'lucky': 5847,
#  'scared': 8917,
#  'ached': 93,
#  'families': 4094,
#  'boring': 1312,
#  'eat': 3547,
#  'turns': 10958,
#  'need': 6615,
#  'purge': 7996,
#  'horrible': 5015,
#  'ask': 649,
#  'permission': 7344,
#  'emotional': 3680,
#  'connection': 2322,
#  'work': 11817,
#  'say': 8902,
#  'affect': 221,
#  'emotionally': 3681,
#  'mentally': 6161,
#  'dumb': 3489,
#  'radicalism': 8095,
#  'whiney': 11671,
#  'shouldn': 9273,
#  'upset': 11236,
#  'eating': 3549,
#  'insides': 5193,
#  'leaving': 5557,
#  'tears': 10394,
#  'eyes': 4041,
#  'ache': 92,
#  'talking': 10332,
#  'david': 2809,
#  'hated': 4793,
#  'didn': 3117,
#  'pre': 7703,
#  'race': 8081,
#  'apprehension': 558,
#  'jaded': 5293,
#  'busy': 1535,
#  'season': 8999,
#  'struggled': 10006,
#  'summon': 10133,
#  'enthusiasm': 3787,
#  'bracken': 1353,
#  'definitely': 2912,
#  'hes': 4919,
#  'grateful': 4595,
#  'sick': 9301,
#  'exhausted': 3947,
#  'sad': 8803,
#  'old': 6912,
#  'close': 2066,
#  'help': 4885,
#  'sidual': 9310,
#  'music': 6508,
#  'demeanor': 2954,
#  'remembered': 8412,
#  'terrible': 10475,
#  'continue': 2405,
#  'totally': 10749,
#  'watch': 11559,
#  'election': 3624,
#  'coverage': 2538,
#  'left': 5565,
#  'hoping': 5008,
#  'guy': 4703,
#  'overly': 7062,
#  'buffoons': 1480,
#  'pretend': 7764,
#  'drained': 3401,
#  'spiritually': 9710,
#  'praying': 7702,
#  'god': 4505,
#  'refresh': 8315,
#  'revive': 8606,
#  'spirit': 9705,
#  'enable': 3707,
#  'spend': 9688,
#  'force': 4293,
#  'hand': 4741,
#  'resolution': 8517,
#  'bc': 963,
#  'coming': 2162,
#  'repeated': 8450,
#  'trip': 10896,
#  'space': 9640,
#  'blame': 1165,
#  'order': 6981,
#  'read': 8181,
#  'actions': 116,
#  'share': 9179,
#  'hiding': 4938,
#  'cheated': 1836,
#  'takes': 10323,
#  'place': 7479,
#  'blog': 1214,
#  'panicked': 7157,
#  'peony': 7302,
#  'told': 10694,
#  'doc': 3306,
#  'looked': 5789,
#  'getting': 4425,
#  'ignored': 5085,
#  'answer': 473,
#  'feelings': 4185,
#  'id': 5070,
#  'wisdom': 11759,
#  'tell': 10431,
#  'far': 4112,
#  'sure': 10179,
#  'awesome': 813,
#  'brain': 1354,
#  'shuts': 9298,
#  'sleep': 9435,
#  'mode': 6336,
#  'reality': 8201,
#  'troubled': 10914,
#  'sorry': 9620,
#  'missing': 6299,
#  'ill': 5088,
#  'soo': 9603,
#  'nice': 6680,
#  'places': 7483,
#  'creation': 2602,
#  'jesus': 5312,
#  'forever': 4299,
#  'nature': 6586,
#  'looks': 5793,
#  'face': 4050,
#  'shows': 9287,
#  'brutality': 1460,
#  'earth': 3533,
#  'loving': 5831,
#  'delicious': 2939,
#  'food': 4286,
#  'piece': 7438,
#  'pizza': 7477,
#  'beers': 1003,
#  'chicken': 1877,
#  'wings': 11744,
#  'revival': 8605,
#  'rochester': 8684,
#  'span': 9646,
#  'style': 10039,
#  'background': 838,
#  'yellow': 11925,
#  'font': 4285,
#  'size': 9382,
#  'disillusioned': 3232,
#  'frustrated': 4356,
#  'british': 1424,
#  'administration': 165,
#  'anguilla': 445,
#  'disturbed': 3289,
#  'distressed': 3284,
#  'members': 6140,
#  'society': 9560,
#  'pimped': 7452,
#  'blatant': 1180,
#  'holds': 4976,
#  'barred': 918,
#  'media': 6105,
#  'create': 2598,
#  'special': 9664,
#  'pipeline': 7465,
#  'ajc': 287,
#  'print': 7796,
#  'products': 7842,
#  'increase': 5143,
#  'ipad': 5262,
#  'app': 521,
#  'downloads': 3379,
#  'groggy': 4636,
#  'stressed': 9971,
#  'blank': 1171,
#  'perform': 7325,
#  'exams': 3911,
#  'quarrel': 8035,
#  'ad': 128,
#  'weve': 11651,
#  'ignore': 5084,
#  'mean': 6087,
#  'tragic': 10796,
#  'loss': 5808,
#  'band': 886,
#  'theyre': 10552,
#  'going': 4511,
#  'today': 10681,
#  'incredibly': 5148,
#  'difficult': 3135,
#  'causing': 1724,
#  'wil': 11718,
#  'organisation': 6990,
#  'foundation': 4317,
#  'cancer': 1608,
#  'choice': 1916,
#  'spent': 9691,
#  'significant': 9322,
#  'reasonable': 8219,
#  'money': 6373,
#  'point': 7563,
#  'entirely': 3791,
#  'inappropriate': 5131,
#  'action': 115,
#  'grocery': 4635,
#  'council': 2508,
#  'said': 8820,
#  'ashamed': 644,
#  'deserve': 3020,
#  'punished': 7980,
#  'messy': 6191,
#  'kitchen': 5398,
#  'better': 1081,
#  'mess': 6182,
#  'reals': 8212,
#  'excited': 3928,
#  'came': 1595,
#  'perfect': 7318,
#  'disconnected': 3202,
#  'dark': 2790,
#  'averted': 795,
#  'savior': 8895,
#  'searing': 8997,
#  'sorrowful': 9619,
#  'scorn': 8956,
#  'accompanied': 68,
#  'gaze': 4400,
#  'continued': 2406,
#  'charade': 1804,
#  'asking': 651,
#  'weepy': 11621,
#  'probably': 7817,
#  'somebody': 9585,
#  'disempowered': 3220,
#  'realize': 8203,
#  'wasnt': 11553,
#  'ready': 8189,
#  'born': 1313,
#  'beautiful': 983,
#  'entering': 3779,
#  'goal': 4503,
#  'embarrassed': 3658,
#  'complaining': 2218,
#  'shake': 9155,
#  'inner': 5183,
#  'ear': 3524,
#  'lightheadedness': 5649,
#  'low': 5833,
#  'energy': 3746,
#  'blood': 1227,
#  'pressure': 7757,
#  'thankfully': 10514,
#  'ok': 6907,
#  'reading': 8185,
#  'unpleasant': 11172,
#  'uniquely': 11141,
#  'writing': 11880,
#  'addy': 153,
#  'gets': 4423,
#  'chance': 1783,
#  'somebodys': 9586,
#  'momma': 6364,
#  'discouraged': 3205,
#  'hold': 4974,
#  'write': 11874,
#  'baby': 830,
#  'habit': 4708,
#  'finally': 4232,
#  'final': 4231,
#  'catalyst': 1709,
#  'sentimental': 9080,
#  'sour': 9631,
#  'wishing': 11766,
#  'culinary': 2693,
#  'collection': 2127,
#  'target': 10351,
#  'title': 10669,
#  'click': 2041,
#  'liked': 5660,
#  'article': 628,
#  'routinely': 8741,
#  'sublime': 10055,
#  'organic': 6989,
#  'meals': 6086,
#  'unwelcome': 11209,
#  'betrayed': 1080,
#  'fell': 4192,
#  'dismayed': 3240,
#  'rage': 8098,
#  'lolhunt': 5773,
#  'use': 11254,
#  'term': 10467,
#  'asshole': 678,
#  'girls': 4455,
#  'saw': 8900,
#  'clicked': 2042,
#  'suddenly': 10098,
#  'repressed': 8472,
#  'surface': 10183,
#  'realized': 8204,
#  'lame': 5452,
#  'poop': 7604,
#  'physically': 7417,
#  'worked': 11819,
#  'trojan': 10907,
#  'll': 5739,
#  'joining': 5323,
#  'january': 5297,
#  'official': 6896,
#  'member': 6139,
#  'lead': 5531,
#  'relatively': 8372,
#  'prefer': 7716,
#  'books': 1295,
#  'best': 1072,
#  'educate': 3581,
#  'kids': 5379,
#  'care': 1656,
#  'strongly': 10001,
#  'issue': 5280,
#  'inadequate': 5129,
#  'socially': 9559,
#  'counter': 2514,
#  'cultural': 2696,
#  'piles': 7446,
#  'buckets': 1470,
#  'whatsoever': 11658,
#  'stay': 9858,
#  'connected': 2320,
#  'crisis': 2633,
#  'urban': 11243,
#  'paint': 7127,
#  'days': 2818,
#  'occasionally': 6857,
#  'visit': 11431,
#  'mother': 6419,
#  'residence': 8507,
#  'crying': 2680,
#  'die': 3120,
#  'believed': 1029,
#  'complaints': 2221,
#  'continously': 2403,
#  'possibility': 7642,
#  'loosing': 5801,
#  'advantage': 200,
#  'numb': 6793,
#  'relief': 8388,
#  'morose': 6408,
#  'month': 6384,
#  'stash': 9844,
#  'overwhelmingly': 7085,
#  'impressive': 5120,
#  'waiting': 11497,
#  'posts': 7654,
#  'comparison': 2204,
#  'mom': 6357,
#  'atheistic': 712,
#  'sloth': 9463,
#  'poem': 7554,
#  'tierd': 10629,
#  'threatened': 10587,
#  'kick': 5371,
#  'ass': 660,
#  'worse': 11839,
#  'listens': 5715,
#  'doesnt': 3317,
#  'brat': 1366,
#  'helps': 4893,
#  'sort': 9621,
#  'thoughts': 10579,
#  'decisions': 2869,
#  'keeping': 5364,
#  'safe': 8812,
#  'millions': 6245,
#  'water': 11564,
#  'thirst': 10566,
#  'hunger': 5056,
#  'custody': 2725,
#  'police': 7581,
#  'case': 1693,
#  'tribals': 10874,
#  'killed': 5381,
#  'termed': 10468,
#  'maoist': 5985,
#  'investigation': 5253,
#  'rejected': 8355,
#  'supposed': 10171,
#  'soldiers': 9575,
#  'lives': 5734,
#  'died': 3121,
#  'protect': 7900,
#  'snubbed': 9538,
#  'center': 1756,
#  'career': 1658,
#  'sanity': 8859,
#  'whew': 11666,
#  'thoughtful': 10577,
#  'believing': 1032,
#  'moments': 6362,
#  'abit': 16,
#  'opinions': 6957,
#  'haha': 4717,
#  'start': 9834,
#  'greet': 4616,
#  'polite': 7584,
#  'took': 10723,
#  'second': 9009,
#  'cognitive': 2110,
#  'psychology': 7942,
#  'lunch': 5857,
#  'missed': 6298,
#  'mystical': 6530,
#  'opportunity': 6961,
#  'shit': 9236,
#  'women': 11791,
#  'ones': 6933,
#  'couple': 2522,
#  'helped': 4886,
#  'revitalise': 8602,
#  'locks': 5758,
#  'physicians': 7418,
#  'lesser': 5594,
#  'degree': 2921,
#  'humiliated': 5051,
#  'profession': 7845,
#  'remains': 8404,
#  'blind': 1196,
#  'stares': 9824,
#  'egg': 3603,
#  'throwing': 10605,
#  'mass': 6038,
#  'public': 7950,
#  'gives': 4459,
#  'ruining': 8768,
#  'charlee': 1814,
#  'living': 5735,
#  'rainy': 8106,
#  'hamburg': 4736,
#  'germany': 4421,
#  'learning': 5549,
#  'express': 4009,
#  'new': 6667,
#  'language': 5466,
#  'remember': 8411,
#  'rediscover': 8289,
#  'freedom': 4329,
#  'moving': 6452,
#  'forward': 4314,
#  'gratitude': 4597,
#  'email': 3651,
#  'nostalgic': 6759,
#  'timer': 10648,
#  'muscles': 6503,
#  'body': 1259,
#  'constantly': 2364,
#  'aching': 101,
#  'happy': 4775,
#  'did': 3115,
#  'friendship': 4345,
#  'handled': 4748,
#  'crappy': 2580,
#  'actually': 125,
#  'post': 7645,
#  'whining': 11672,
#  'publicly': 7954,
#  'ridiculous': 8636,
#  'longer': 5781,
#  'worry': 11837,
#  'unhappy': 11121,
#  'amounted': 400,
#  'positive': 7635,
#  'effects': 3596,
#  'treatment': 10853,
#  'stop': 9929,
#  'blaming': 1168,
#  'figure': 4222,
#  'radio': 8096,
#  'appearances': 531,
#  'someday': 9587,
#  'anticipation': 484,
#  'eternal': 3856,
#  'repetition': 8454,
#  'futile': 4380,
#  'heartbroken': 4845,
#  'fantastic': 4109,
#  'genius': 4411,
#  'definite': 2911,
#  'signs': 9325,
#  'sinus': 9361,
#  'infection': 5164,
#  'lungs': 5859,
#  'sinking': 9357,
#  'makes': 5931,
#  'doesn': 3316,
#  'basically': 933,
#  'fired': 4244,
#  'free': 4328,
#  'blessing': 1193,
#  'decided': 2865,
#  'push': 8007,
#  'ups': 11235,
#  'figured': 4223,
#  'upper': 11233,
#  'workout': 11824,
#  'sit': 9370,
#  'blow': 1232,
#  'nose': 6757,
#  'loved': 5825,
#  'cool': 2455,
#  'knee': 5400,
#  'angry': 442,
#  'seemingly': 9029,
#  'endless': 3733,
#  'hours': 5030,
#  'played': 7512,
#  'therapist': 10538,
#  'daily': 2759,
#  'phone': 7403,
#  'throws': 10607,
#  'furthest': 4377,
#  'illusions': 5091,
#  'guess': 4674,
#  'foolish': 4289,
#  'wrong': 11883,
#  'wins': 11749,
#  'faith': 4080,
#  'posted': 7646,
#  'expected': 3973,
#  'sulk': 10124,
#  'moan': 6323,
#  'nag': 6538,
#  'human': 5045,
#  'yes': 11931,
#  'aku': 293,
#  'ni': 6677,
#  'bila': 1110,
#  'tengok': 10457,
#  'talked': 10331,
#  'hurts': 5061,
#  'intentionally': 5224,
#  'stuffs': 10026,
#  'frequent': 4333,
#  'russian': 8787,
#  'cooking': 2453,
#  'price': 7779,
#  'november': 6784,
#  'st': 9782,
#  'haunted': 4804,
#  'house': 5031,
#  'carving': 1690,
#  'pumpkins': 7975,
#  'watching': 11563,
#  'halloween': 4732,
#  'based': 928,
#  'movies': 6450,
#  'pocus': 7550,
#  'casper': 1699,
#  'appreciate': 553,
#  'mindful': 6254,
#  'judged': 5339,
#  'returned': 8576,
#  'apartment': 506,
#  'run': 8774,
#  'beaten': 980,
#  'physical': 7416,
#  'condition': 2277,
#  'conservatives': 2342,
#  'ways': 11578,
#  'unimportant': 11131,
#  'unloved': 11160,
#  'nuisance': 6791,
#  'idiotic': 5076,
#  'depressed': 3000,
#  'number': 6795,
#  'orezi': 6988,
#  'idle': 5079,
#  'comic': 2161,
#  'ended': 3730,
#  'sketchbook': 9394,
#  'instead': 5205,
#  'confessed': 2286,
#  'loses': 5806,
#  'forced': 4294,
#  'leave': 5554,
#  'military': 6237,
#  'chopped': 1927,
#  'machete': 5883,
#  'opposite': 6964,
#  'tagged': 10311,
#  'overtly': 7075,
#  'identify': 5073,
#  'discussion': 3217,
#  'topics': 10728,
#  'void': 11457,
#  'shouldnt': 9274,
#  'hgave': 4928,
#  'spak': 9644,
#  'yelled': 11923,
#  'blamed': 1166,
#  'oh': 6903,
#  'ylur': 11937,
#  'fault': 4146,
#  'bring': 1416,
#  'obstacles': 6850,
#  'confused': 2309,
#  'picking': 7425,
#  'path': 7233,
#  'images': 5095,
#  'husband': 5062,
#  'town': 10769,
#  'sipping': 9364,
#  'glass': 4473,
#  'red': 8284,
#  'wine': 11742,
#  'having': 4808,
#  'emotions': 3683,
#  'running': 8777,
#  'glad': 4461,
#  'allowing': 343,
#  'compassionate': 2206,
#  'bits': 1147,
#  'waves': 11573,
#  'rushing': 8783,
#  'permanently': 7342,
#  'cuttings': 2737,
#  'trimmed': 10892,
#  'lanky': 5469,
#  'growth': 4656,
#  'hadnt': 4715,
#  'filled': 4226,
#  'hung': 5055,
#  'window': 11737,
#  'sink': 9356,
#  'cheer': 1847,
#  'shout': 9276,
#  'lord': 5803,
#  'analyze': 414,
#  'intention': 5223,
#  'buying': 1544,
#  'jewelry': 5313,
#  'travel': 10838,
#  'experience': 3980,
#  'understand': 11071,
#  'partner': 7205,
#  'hear': 4837,
#  'wow': 11854,
#  'shes': 9215,
#  'hot': 5027,
#  'yeah': 11914,
#  'fucking': 4362,
#  'amazing': 371,
#  'chiefs': 1886,
#  'lmfao': 5742,
#  'inside': 5192,
#  'wanna': 11525,
#  'hide': 4936,
#  'miss': 6297,
#  'goodbye': 4519,
#  'looking': 5791,
#  'helplessness': 4892,
#  'small': 9478,
#  'arm': 600,
#  'claimed': 1990,
#  'barely': 912,
#  'walk': 11505,
#  'yoga': 11939,
#  'procrastinate': 7829,
#  'excuse': 3935,
#  'rotten': 8732,
#  'woke': 11783,
#  'brody': 1432,
#  'feature': 4167,
#  'book': 1291,
#  'edited': 3574,
#  'nickwilford': 6689,
#  'list': 5708,
#  'xy': 11898,
#  'waxing': 11575,
#  'profanely': 7843,
#  'addition': 145,
#  'effort': 3599,
#  'organized': 6995,
#  'reliable': 8384,
#  'spain': 9643,
#  'countries': 2519,
#  'planet': 7493,
#  'decision': 2868,
#  'worried': 11835,
#  'taking': 10324,
#  'daughters': 2807,
#  'christmas': 1943,
#  'scheduled': 8935,
#  'gross': 4640,
#  'encourages': 3721,
#  'drink': 3441,
#  'coffee': 2109,
#  'maybe': 6076,
#  'suitcase': 10121,
#  'months': 6385,
#  'homeless': 4984,
#  'half': 4727,
#  'company': 2199,
#  'wish': 11762,
#  'president': 7751,
#  'hardly': 4783,
#  'quiet': 8055,
#  'smiling': 9497,
#  'related': 8366,
#  'mores': 6399,
#  'pity': 7476,
#  'sweet': 10250,
#  'mountain': 6434,
#  'wisp': 11767,
#  'starlight': 9828,
#  'carnival': 1674,
#  'potential': 7662,
#  'simply': 9342,
#  'described': 3015,
#  'deal': 2832,
#  'mope': 6395,
#  'bed': 993,
#  'wallow': 11514,
#  'choose': 1923,
#  'accepting': 56,
#  'disadvantaged': 3177,
#  'grew': 4620,
#  'england': 3757,
#  'great': 4602,
#  'emphasis': 3690,
#  'somelike': 9588,
#  'putting': 8016,
#  'unprotected': 11177,
#  'class': 2005,
#  'count': 2512,
#  'link': 5694,
#  'reprogramming': 8476,
#  'process': 7825,
#  'outline': 7029,
#  'unsure': 11199,
#  'believe': 1028,
#  'unhealthy': 11122,
#  'obsession': 6848,
#  'beauty': 985,
#  'constant': 2361,
#  ...}

# %%
df1 = df.sample(12000)

# %%
#df1.to_csv('Emotion_Analysis.csv')

# %%
X = bow.fit_transform(df1['text'])
y = df1['label']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=23)

# %% [markdown]
# # KNN

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5254166666666666

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train,y_train)
y_pred = nb.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8195833333333333

# %% [markdown]
# # Decssion Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_pred = dt.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.86625

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC
sv = SVC()
sv.fit(X_train,y_train)
y_pred = sv.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.89125

# %%
import pickle

# %%
pickle.dump(dt,open("ea.pkl","wb"))

# %%
model = pickle.load(open("ea.pkl","rb"))

# %%
pickle.dump(bow,open("bow1.pkl","wb"))

# %%
bow = pickle.load(open("bow1.pkl","rb"))

# %%
df1
# Out:
#                                                     text  label
# 3685   i had this relaxing feeling everybody was so f...      1
# 2694   i really feel superior to several folks but no...      1
# 6471   i live in dublin they dont have it in any shop...      3
# 5961   i look back and though i m thankful for the st...      2
# 1603                i feel so needy and lonely right now      0
# ...                                                  ...    ...
# 11595  i feel absolutely amazing when i do things tha...      5
# 8005   i remember feeling after the third bong hit th...      4
# 8169   i times has two aspect to have given me feelin...      4
# 11804  i feel like a sasquatch but im curious to see ...      5
# 7038   i feel like i have to at least glance in their...      3
#
# [12000 rows x 2 columns]

# %%
df["text"][3685]
# Out:
# 'i had this relaxing feeling everybody was so friendly and encouraging'

# %%
df["text"][2694]
# Out:
# 'i really feel superior to several folks but not in an i am much better than you'

# %%
df["text"][6471]
# Out:
# 'i live in dublin they dont have it in any shop only gothic and download i dont like to download and anyways its nowhere where i can find to download it i played g but i cant get fuckin notr feelin so fucked up right now'

# %%
df["text"][8169]
# Out:
# 'i times has two aspect to have given me feeling uncertain very greatly as for'

# %%
df["text"][8005]
# Out:
# 'i remember feeling after the third bong hit that i was being pressured into this'

# %%
df["text"][7038]
# Out:
# 'i feel like i have to at least glance in their direction or say hi when they pass by for fear of looking like a rude bitch occupying the desk up front'
